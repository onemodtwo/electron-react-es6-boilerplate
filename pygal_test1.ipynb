# %%
import pygal
from jupygal import show

# %%
z = pygal.Bar()

# %%
z.add('digits', range(10))
show(z)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#     <script type="text/javascript" src="http://kozea.github.com/pygal.js/latest/pygal-tooltips.min.js"></script>
#   </head>
#   <body>
#     <figure>
# ...

# %%
show(z, 'static')
# Out:
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-583f379d-efbf-4cf9-b5d4-ea2531cba76e" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2018-02-21--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-583f379d-efbf-4cf9-b5d4-ea2531cba76e{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-583f379d-efbf-4cf9-b5d4-ea2531cba76e .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-583f379d-efbf-4cf9-b5d4-ea2531cba76e .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-583f379d-efbf-4cf9-b5d4-ea2531cba76e .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-583f379d-efbf-4cf9-b5d4-ea2531cba76e .axis text.major{font-family:Consolas,"Liberation
# ...

# %%
b = pygal.Bar(title='Bar Chart')
b.add('digits1', range(10))
b.add('digits2', range(7))
show(b)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#     <script type="text/javascript" src="http://kozea.github.com/pygal.js/latest/pygal-tooltips.min.js"></script>
#   </head>
#   <body>
#     <figure>
# ...

# %%
show(b, 'static')
# Out:
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-6bdd8e27-6d55-40cd-913d-2ee9f5a245b3" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2018-02-21--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-6bdd8e27-6d55-40cd-913d-2ee9f5a245b3{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-6bdd8e27-6d55-40cd-913d-2ee9f5a245b3 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6bdd8e27-6d55-40cd-913d-2ee9f5a245b3 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6bdd8e27-6d55-40cd-913d-2ee9f5a245b3 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6bdd8e27-6d55-40cd-913d-2ee9f5a245b3 .axis text.major{font-family:Consolas,"Liberation
# ...
